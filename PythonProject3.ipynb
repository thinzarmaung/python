# %% [markdown]
# <a href="https://colab.research.google.com/github/thinzarmaung/python/blob/main/PythonProject3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#from google.colab import files
#uploaded = files.upload()
# Out:
#      <input type="file" id="files-9b74940d-5bef-470d-b9fa-fefbcd45c21b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b74940d-5bef-470d-b9fa-fefbcd45c21b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/NYPD_Arrest_Data__Year_to_Date__20231219.csv')
df.describe()
# Out:
#          ARREST_KEY          PD_CD          KY_CD  ARREST_PRECINCT  \
# count  1.700950e+05  170095.000000  170082.000000    170095.000000
# mean   2.683705e+08     425.242200     249.766342        63.423569
# std    4.027782e+06     275.312255     148.500439        34.596068
# min    2.611809e+08       2.000000     101.000000         1.000000
# 25%    2.649555e+08     114.000000     113.000000        40.000000
# 50%    2.685036e+08     397.000000     236.000000        62.000000
# 75%    2.718261e+08     705.000000     344.000000       101.000000
# max    2.752350e+08     997.000000     995.000000       123.000000
#
#        JURISDICTION_CODE    X_COORD_CD     Y_COORD_CD       Latitude  \
# count      170095.000000  1.700950e+05  170095.000000  170095.000000
# mean            0.945918  1.005863e+06  208326.176925      40.738196
# std             7.683909  2.152952e+04   29737.941320       0.128134
# min             0.000000  0.000000e+00       0.000000       0.000000
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['ARREST_KEY', 'ARREST_DATE', 'PD_CD', 'PD_DESC', 'KY_CD', 'OFNS_DESC',
#        'LAW_CODE', 'LAW_CAT_CD', 'ARREST_BORO', 'ARREST_PRECINCT',
#        'JURISDICTION_CODE', 'AGE_GROUP', 'PERP_SEX', 'PERP_RACE', 'X_COORD_CD',
#        'Y_COORD_CD', 'Latitude', 'Longitude', 'New Georeferenced Column'],
#       dtype='object')

# %%
df_boro=df.groupby(['ARREST_BORO'])['ARREST_BORO'].count()
df_boro.head(50)
# Out:
# ARREST_BORO
# B    39957
# K    46825
# M    39652
# Q    36246
# S     7415
# Name: ARREST_BORO, dtype: int64

# %%
df2=df[['ARREST_DATE',	'PD_CD',	'PD_DESC',	'LAW_CODE',	'ARREST_BORO','ARREST_PRECINCT','AGE_GROUP','PERP_SEX','PERP_RACE']]
df2
# Out:
#        ARREST_DATE  PD_CD                         PD_DESC    LAW_CODE  \
# 0         1/1/2023    109        ASSAULT 2,1,UNCLASSIFIED  PL 1200501
# 1         2/3/2023    515     CONTROLLED SUBSTANCE,SALE 3  PL 2203901
# 2        2/15/2023    105               STRANGULATION 1ST  PL 1211200
# 3         1/4/2023    105               STRANGULATION 1ST  PL 1211200
# 4        2/13/2023    109        ASSAULT 2,1,UNCLASSIFIED  PL 12005WX
# ...            ...    ...                             ...         ...
# 170090    7/7/2023    397  ROBBERY,OPEN AREA UNCLASSIFIED  PL 1601002
# 170091   8/18/2023    681      CHILD, ENDANGERING WELFARE  PL 2601001
# 170092   9/13/2023    969  TRAFFIC,UNCLASSIFIED INFRACTIO  VTL051101A
# 170093   6/15/2023    490    STOLEN PROPERTY 3,POSSESSION  PL 1654000
# 170094   7/28/2023    729  FORGERY,ETC.,UNCLASSIFIED-FELO  PL 1702500
#
#        ARREST_BORO  ARREST_PRECINCT AGE_GROUP PERP_SEX       PERP_RACE
# ...

# %%
df2_Qu = df2[(df2['ARREST_BORO'] == "Q")]
df2_Qu
# Out:
#        ARREST_DATE  PD_CD                         PD_DESC    LAW_CODE  \
# 5        1/17/2023    105               STRANGULATION 1ST  PL 1211200
# 11        2/2/2023    101                       ASSAULT 3  PL 1200001
# 18       2/18/2023    101                       ASSAULT 3  PL 1200001
# 22        5/3/2023    153                          RAPE 3  PL 1302503
# 29       6/14/2023    105               STRANGULATION 1ST  PL 1211200
# ...            ...    ...                             ...         ...
# 170070   8/30/2023    705              FORGERY,ETC.-MISD.  PL 1702000
# 170080   8/17/2023    639         AGGRAVATED HARASSMENT 2  PL 2403002
# 170081   6/13/2023    729  FORGERY,ETC.,UNCLASSIFIED-FELO  PL 1702500
# 170084   5/25/2023    779  PUBLIC ADMINISTRATION,UNCLASSI  PL 215510B
# 170086   7/25/2023    969  TRAFFIC,UNCLASSIFIED INFRACTIO  VTL051101A
#
#        ARREST_BORO  ARREST_PRECINCT AGE_GROUP PERP_SEX       PERP_RACE
# ...

# %%
df2_Q65 = df2[(df2['ARREST_BORO'] == "Q")&(df2['AGE_GROUP']=="65+")&(df2['PERP_SEX']=='F')]
df2_Q65
# Out:
#        ARREST_DATE  PD_CD                         PD_DESC    LAW_CODE  \
# 4465      3/9/2023    268              CRIMINAL MIS 2 & 3  PL 1450502
# 4577     1/10/2023    339  LARCENY,PETIT FROM OPEN AREAS,  PL 1552500
# 7018     5/15/2023    339  LARCENY,PETIT FROM OPEN AREAS,  PL 1552500
# 8654     1/16/2023    101                       ASSAULT 3  PL 1200001
# 10975     5/6/2023    969  TRAFFIC,UNCLASSIFIED INFRACTIO  VTL1192AI1
# ...            ...    ...                             ...         ...
# 166971   8/29/2023    268              CRIMINAL MIS 2 & 3  PL 1450502
# 167266    9/6/2023    511  CONTROLLED SUBSTANCE, POSSESSI  PL 2200300
# 167648   7/13/2023    681      CHILD, ENDANGERING WELFARE  PL 2601001
# 167848   7/12/2023    109        ASSAULT 2,1,UNCLASSIFIED  PL 1200501
# 169689   7/15/2023    339  LARCENY,PETIT FROM OPEN AREAS,  PL 1552500
#
#        ARREST_BORO  ARREST_PRECINCT AGE_GROUP PERP_SEX  \
# 4465             Q              113       65+        F
# ...

# %%
df2_Q65F=df2_Q65[df2_Q65['ARREST_PRECINCT']==110]
df2_Q65F
# Out:
#        ARREST_DATE  PD_CD                                    PD_DESC  \
# 4577     1/10/2023    339             LARCENY,PETIT FROM OPEN AREAS,
# 14245     2/1/2023    339             LARCENY,PETIT FROM OPEN AREAS,
# 15112    3/16/2023    339             LARCENY,PETIT FROM OPEN AREAS,
# 15964    5/13/2023    439  LARCENY,GRAND FROM OPEN AREAS, UNATTENDED
# 23728    8/13/2023    339             LARCENY,PETIT FROM OPEN AREAS,
# 24849     6/5/2023    259           CRIMINAL MISCHIEF,UNCLASSIFIED 4
# 25389    4/23/2023    109                   ASSAULT 2,1,UNCLASSIFIED
# 32371    5/31/2023    339             LARCENY,PETIT FROM OPEN AREAS,
# 42826     4/5/2023    419             LARCENY,GRAND FROM PERSON,UNCL
# 45057     9/5/2023    339             LARCENY,PETIT FROM OPEN AREAS,
# 56670    2/17/2023    339             LARCENY,PETIT FROM OPEN AREAS,
# 56841    8/15/2023    339             LARCENY,PETIT FROM OPEN AREAS,
# 62354    9/12/2023    101                                  ASSAULT 3
# ...

# %%
df2_Q18 = df2[(df2['ARREST_BORO'] == "Q")&(df2['AGE_GROUP']=="<18")]
df2_Q18
# Out:
#        ARREST_DATE  PD_CD                         PD_DESC    LAW_CODE  \
# 11        2/2/2023    101                       ASSAULT 3  PL 1200001
# 67       7/17/2023    101                       ASSAULT 3  PL 1200001
# 252      1/30/2023    339  LARCENY,PETIT FROM OPEN AREAS,  PL 1552500
# 378       4/6/2023    397  ROBBERY,OPEN AREA UNCLASSIFIED  PL 1601504
# 389      1/19/2023    681      CHILD, ENDANGERING WELFARE  PL 2601001
# ...            ...    ...                             ...         ...
# 169425    7/5/2023    397  ROBBERY,OPEN AREA UNCLASSIFIED  PL 1601001
# 169622   5/29/2023    792      CRIMINAL POSSESSION WEAPON  PL 265031B
# 169674   7/19/2023    268              CRIMINAL MIS 2 & 3  PL 1450502
# 169873   9/18/2023    101                       ASSAULT 3  PL 1200001
# 170064   6/27/2023    269  MISCHIEF,CRIMINAL,    UNCL 2ND  PL 145001H
#
#        ARREST_BORO  ARREST_PRECINCT AGE_GROUP PERP_SEX  \
# 11               Q              108       <18        M
# ...

# %%
df2_Qu.groupby(['AGE_GROUP'])['PD_CD'].max()
# Out:
# AGE_GROUP
# 18-24    997
# 25-44    997
# 45-64    969
# 65+      969
# <18      848
# Name: PD_CD, dtype: int64

# %%
sns.displot(df2['ARREST_BORO'])

# %%
sns.pairplot(df2_Q65)

# %%
sns.pairplot(df2_Qu,hue='AGE_GROUP')

# %%
sns.boxplot(x='ARREST_PRECINCT', y='PD_CD', data=df2_Q65)
# Out:
# <Axes: xlabel='ARREST_PRECINCT', ylabel='PD_CD'>

# %%
df2_Qu.groupby(['AGE_GROUP'])['PD_CD'].max().plot(kind='bar')
plt.title('Arrest at Queens by Age')
# Out:
# Text(0.5, 1.0, 'Arrest at Queens by Age')

# %% [markdown]
# Conclustion
#
# Arrest Data in Queens Borough.
# Number of count of over 65 and Female of Perpetrator.
