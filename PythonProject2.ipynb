# %% [markdown]
# <a href="https://colab.research.google.com/github/thinzarmaung/python/blob/main/PythonProject2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
df=pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')
df
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
#To clean miss values Race, gender, weight,

# %%
#Making a list of missing value types
missing_values=["?"]
df=pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')
df
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
df_race=df.groupby(['race'])['race'].count()
df_race.head(20)
# Out:
# race
# ?                   2273
# AfricanAmerican    19210
# Asian                641
# Caucasian          76099
# Hispanic            2037
# Other               1506
# Name: race, dtype: int64

# %%
df_gender_race=df.groupby(['gender'])['race'].count()
df_gender_race.head(20)
# Out:
# gender
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: race, dtype: int64

# %%
#how to filter "unknown/invalid"
df2=df[['encounter_id',	'patient_nbr',	'race',	'gender',	'age','medical_specialty','diabetesMed']]
df2
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 0            2278392      8222157        Caucasian  Female   [0-10)
# 1             149190     55629189        Caucasian  Female  [10-20)
# 2              64410     86047875  AfricanAmerican  Female  [20-30)
# 3             500364     82442376        Caucasian    Male  [30-40)
# 4              16680     42519267        Caucasian    Male  [40-50)
# ...              ...          ...              ...     ...      ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)
# 101763     443854148     41088789        Caucasian    Male  [70-80)
# 101764     443857166     31693671        Caucasian  Female  [80-90)
# 101765     443867222    175429310        Caucasian    Male  [70-80)
#
#                medical_specialty diabetesMed
# 0       Pediatrics-Endocrinology          No
# 1                              ?         Yes
# ...

# %%
df_race = df2[(df2['race'] == "Asian")]
df_race
# Out:
#         encounter_id  patient_nbr   race  gender      age  \
# 200          2655870       716805  Asian    Male  [60-70)
# 384          3628932      1660932  Asian  Female  [50-60)
# 414          3783912    100533195  Asian    Male  [70-80)
# 649          5122188      6490224  Asian    Male  [50-60)
# 766          5929704     90056529  Asian    Male  [60-70)
# ...              ...          ...    ...     ...      ...
# 101494     440179892    100366497  Asian    Male  [80-90)
# 101501     440198876     89008308  Asian  Female  [80-90)
# 101595     441488168    188970179  Asian  Female  [70-80)
# 101600     441502886     33673167  Asian    Male  [60-70)
# 101666     442576412    186544184  Asian  Female  [30-40)
#
#           medical_specialty diabetesMed
# 200              Cardiology          No
# 384        InternalMedicine         Yes
# 414                       ?          No
# 649     Hematology/Oncology         Yes
# 766                       ?         Yes
# ...

# %%
df_gender=df2[(df2['gender'] == "Unknown/Invalid")]
df_gender
# Out:
#        encounter_id  patient_nbr   race           gender      age
# 30506      98634858    100695042  Other  Unknown/Invalid  [70-80)
# 75551     226864668     60524946      ?  Unknown/Invalid  [60-70)
# 82573     257364294     78119847      ?  Unknown/Invalid  [70-80)

# %%
df3=df2.replace('Unknown/Invalid','Female')
df3
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 0            2278392      8222157        Caucasian  Female   [0-10)
# 1             149190     55629189        Caucasian  Female  [10-20)
# 2              64410     86047875  AfricanAmerican  Female  [20-30)
# 3             500364     82442376        Caucasian    Male  [30-40)
# 4              16680     42519267        Caucasian    Male  [40-50)
# ...              ...          ...              ...     ...      ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)
# 101763     443854148     41088789        Caucasian    Male  [70-80)
# 101764     443857166     31693671        Caucasian  Female  [80-90)
# 101765     443867222    175429310        Caucasian    Male  [70-80)
#
#                medical_specialty diabetesMed
# 0       Pediatrics-Endocrinology          No
# 1                              ?         Yes
# ...

# %%
df4=df3[(df3['gender'] == "Unknown/Invalid")]
df4
# Out:
# Empty DataFrame
# Columns: [encounter_id, patient_nbr, race, gender, age]
# Index: []

# %%
#To Drop ? at medical specialty

# %%
df_r = df2[(df2['race'] == "Asian") & (df2['gender']== "Female")]
df_r
# Out:
#         encounter_id  patient_nbr   race  gender      age
# 384          3628932      1660932  Asian  Female  [50-60)
# 804          6337620     77025807  Asian  Female  [60-70)
# 1073         7972380      1660932  Asian  Female  [50-60)
# 1225         8691432      2528361  Asian  Female  [50-60)
# 2193        14290872    105084666  Asian  Female  [70-80)
# ...              ...          ...    ...     ...      ...
# 101422     439040618    134738807  Asian  Female  [70-80)
# 101432     439100198     33942636  Asian  Female  [70-80)
# 101501     440198876     89008308  Asian  Female  [80-90)
# 101595     441488168    188970179  Asian  Female  [70-80)
# 101666     442576412    186544184  Asian  Female  [30-40)
#
# [318 rows x 5 columns]

# %%
#Asia, Female, Family/General Practice
df_AS_F_Dia = df3[(df3['race'] == "Asian") & (df3['gender']== "Female")&(df3['medical_specialty']=='Family/GeneralPractice')]
df_AS_F_Dia
# Out:
#        encounter_id  patient_nbr   race  gender      age  \
# 1073        7972380      1660932  Asian  Female  [50-60)
# 2193       14290872    105084666  Asian  Female  [70-80)
# 3237       20297574      1660932  Asian  Female  [50-60)
# 6378       31726944      1660932  Asian  Female  [50-60)
# 6872       33433452      1660932  Asian  Female  [50-60)
# 9778       42109266      1660932  Asian  Female  [50-60)
# 10242      43617840      1660932  Asian  Female  [50-60)
# 11485      47488404     18615978  Asian  Female  [70-80)
# 21444      74734830     22484988  Asian  Female  [40-50)
# 22187      76698234    105084666  Asian  Female  [70-80)
# 36294     111702348     30234393  Asian  Female  [80-90)
# 39908     124091460     93377601  Asian  Female  [60-70)
# 42237     130341906     36163917  Asian  Female  [60-70)
# 49005     148882062     66625191  Asian  Female  [70-80)
# 51358     153291414     94717026  Asian  Female  [60-70)
# ...

# %%
#Asia, Female, Family/General Practice
df_US_F_Dia = df3[(df3['race'] == "AfricanAmerican") & (df3['gender']== "Female")&(df3['medical_specialty']=='Family/GeneralPractice')]
df_US_F_Dia
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 146          2356308       608841  AfricanAmerican  Female  [50-60)
# 311          3185130      2579427  AfricanAmerican  Female  [70-80)
# 370          3557748      1582326  AfricanAmerican  Female  [10-20)
# 586          4736166      1125135  AfricanAmerican  Female  [70-80)
# 615          4890552       355986  AfricanAmerican  Female  [60-70)
# ...              ...          ...              ...     ...      ...
# 97401      388390526     45403434  AfricanAmerican  Female  [60-70)
# 97920      394352090    103792869  AfricanAmerican  Female  [50-60)
# 97944      394851098    106966935  AfricanAmerican  Female  [70-80)
# 98827      405635042    109553571  AfricanAmerican  Female  [30-40)
# 100669     429082718     92919915  AfricanAmerican  Female  [50-60)
#
#              medical_specialty diabetesMed
# 146     Family/GeneralPractice         Yes
# 311     Family/GeneralPractice         Yes
# ...

# %%
df_AS_F_Dia.groupby(['age']).count()
# Out:
#          encounter_id  patient_nbr  race  gender  medical_specialty  \
# age
# [40-50)             3            3     3       3                  3
# [50-60)             8            8     8       8                  8
# [60-70)             5            5     5       5                  5
# [70-80)             7            7     7       7                  7
# [80-90)             6            6     6       6                  6
#
#          diabetesMed
# age
# [40-50)            3
# [50-60)            8
# [60-70)            5
# [70-80)            7
# [80-90)            6

# %%
df_US_F_Dia.groupby(['age']).count()
# Out:
#           encounter_id  patient_nbr  race  gender  medical_specialty  \
# age
# [10-20)              5            5     5       5                  5
# [20-30)             33           33    33      33                 33
# [30-40)             65           65    65      65                 65
# [40-50)            177          177   177     177                177
# [50-60)            229          229   229     229                229
# [60-70)            170          170   170     170                170
# [70-80)            206          206   206     206                206
# [80-90)            116          116   116     116                116
# [90-100)            27           27    27      27                 27
#
#           diabetesMed
# age
# [10-20)             5
# [20-30)            33
# [30-40)            65
# [40-50)           177
# [50-60)           229
# [60-70)           170
# [70-80)           206
# [80-90)           116
# [90-100)           27

# %%
df_race_gender=df.groupby(['race'])['gender'].count()
df_race_gender.head(20)
# Out:
# race
# ?                   2273
# AfricanAmerican    19210
# Asian                641
# Caucasian          76099
# Hispanic            2037
# Other               1506
# Name: gender, dtype: int64

# %%
#To merge/ To append Asiana and US
frames = [df_AS_F_Dia, df_US_F_Dia]

AS_US = pd.concat(frames)
display(AS_US)
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 1073         7972380      1660932            Asian  Female  [50-60)
# 2193        14290872    105084666            Asian  Female  [70-80)
# 3237        20297574      1660932            Asian  Female  [50-60)
# 6378        31726944      1660932            Asian  Female  [50-60)
# 6872        33433452      1660932            Asian  Female  [50-60)
# ...              ...          ...              ...     ...      ...
# 97401      388390526     45403434  AfricanAmerican  Female  [60-70)
# 97920      394352090    103792869  AfricanAmerican  Female  [50-60)
# 97944      394851098    106966935  AfricanAmerican  Female  [70-80)
# 98827      405635042    109553571  AfricanAmerican  Female  [30-40)
# 100669     429082718     92919915  AfricanAmerican  Female  [50-60)
#
#              medical_specialty diabetesMed
# 1073    Family/GeneralPractice         Yes
# 2193    Family/GeneralPractice         Yes
# ...

# %%
# scatter plot
AS_US.plot(kind='scatter',
        x='race',
        y='age',
        color='blue')

# set the title
plt.title('DiabetesMed of Asian and AfricanAmerican by Age')

# show the plot
plt.show()

# %%
df_US_F_Dia.plot.box()
# Out:
# <Axes: >

# %%
ser=df_US_F_Dia.Series(np.random.randn(1000))
ser.plot.kde();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-86-b28793d5b679> in <cell line: 1>()
# ----> 1 ser=df_US_F_Dia.Series(np.random.randn(1000))
#       2 ser.plot.kde();
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Series'

# %%
#to compare by race with lineplot
#to compare more medical specialty

# %%
# Get current axis
''' ax = plt.gca()

# line plot for math marks
AS_US.plot(kind='line',
        x='race',
        y='age',
        color='green', ax=ax)

# line plot for physics marks
AS_US.plot(kind='line', x='race',
        y='age',
        color='blue', ax=ax)



# set the title
plt.title('LinePlots')

# show the plot
plt.show() '''
# Out:
# " ax = plt.gca() \n  \n# line plot for math marks \nAS_US.plot(kind='line', \n        x='race', \n        y='age', \n        color='green', ax=ax) \n  \n# line plot for physics marks \nAS_US.plot(kind='line', x='race', \n        y='age', \n        color='blue', ax=ax) \n  \n\n  \n# set the title \nplt.title('LinePlots') \n  \n# show the plot \nplt.show() "

# %%
# Pie Chart: Department-wise Salary distribution

df_employees.groupby('Department')['Salary'].sum().plot.pie(title='Department-wise Salary Distribution', autopct='%1.1f%%')

# %%
#to compare by race with lineplot
#to compare more medical specialty
