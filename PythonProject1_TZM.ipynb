# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
#Cleansing Data
df_rename=df.rename(columns={'Percent Scoring Below 65':'% Scoring Below 65', 'Percent Scoring 65 or Above': '% Scoring 65 or Above','Percent Scoring 80 or Above':'% Scoring 80 or Above','Percent Scoring CR':'% Scoring CR' })
df_rename
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %%
#Filter by Shcool Name and Year


df_QuYear=df_rename[(df_rename['Year']==2015)& (df_rename['School Name']=='Queens High School for Language Studies')&(df_rename['Number Scoring Below 65'] != 's')]
df_QuYear.head(50)
# Out:
#        School DBN                              School Name School Level  \
# 14036      25Q241  Queens High School for Language Studies  High school
# 14039      25Q241  Queens High School for Language Studies  High school
# 14046      25Q241  Queens High School for Language Studies  High school
# 14049      25Q241  Queens High School for Language Studies  High school
# 14052      25Q241  Queens High School for Language Studies  High school
# 14055      25Q241  Queens High School for Language Studies  High school
# 14057      25Q241  Queens High School for Language Studies  High school
# 14060      25Q241  Queens High School for Language Studies  High school
# 14063      25Q241  Queens High School for Language Studies  High school
# 44575      25Q241  Queens High School for Language Studies  High school
# 44579      25Q241  Queens High School for Language Studies  High school
# 44580      25Q241  Queens High School for Language Studies  High school
# ...

# %%
df_QuLang=df_rename[df_rename['School Name']=='Queens High School for Language Studies']
df_QuLang
# Out:
#        School DBN                              School Name School Level  \
# 14036      25Q241  Queens High School for Language Studies  High school
# 14037      25Q241  Queens High School for Language Studies  High school
# 14038      25Q241  Queens High School for Language Studies  High school
# 14039      25Q241  Queens High School for Language Studies  High school
# 14040      25Q241  Queens High School for Language Studies  High school
# ...           ...                                      ...          ...
# 191967     25Q241  Queens High School for Language Studies  High school
# 191968     25Q241  Queens High School for Language Studies  High school
# 191969     25Q241  Queens High School for Language Studies  High school
# 191970     25Q241  Queens High School for Language Studies  High school
# 191971     25Q241  Queens High School for Language Studies  High school
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# ...

# %%
df_SchYear=df_rename.groupby(['School Name'])['Year'].count()
df_SchYear.head(20)
# Out:
# School Name
# 47 The American Sign Language and English Secondar    356
# A. Philip Randolph Campus High School                 459
# ACORN Community High School                           364
# Abraham Lincoln High School                           480
# Abraham Lincoln Yabc                                  248
# Academy For Personal Leadership And Excellence         61
# Academy for Careers in Television and Film            447
# Academy for College Preparation and Career Explora    388
# Academy for Conservation and the Environment          399
# Academy for Environmental Leadership                  343
# Academy for Health Careers                            303
# Academy for Language and Technology                   268
# Academy for New Americans                               5
# Academy for Scholarship and Entrepreneurship: A Co    376
# Academy for Social Action                             325
# Academy for Software Engineering                      428
# ...

# %%
df_rename.describe()
# Out:
#                 Year   Total Tested
# count  212331.000000  212331.000000
# mean     2015.956069      49.364200
# std         0.799726      93.023576
# min      2015.000000       1.000000
# 25%      2015.000000       5.000000
# 50%      2016.000000      20.000000
# 75%      2017.000000      57.000000
# max      2017.000000    1729.000000

# %%
df_examyear=df_rename.groupby(['Regents Exam'])['Year'].count()
df_examyear.tail()
# Out:
# Regents Exam
# Living Environment                 25539
# Physical Settings/Chemistry        11670
# Physical Settings/Earth Science    15971
# Physical Settings/Physics           5799
# U.S. History and Government        20426
# Name: Year, dtype: int64

# %%
df_examyear.hist()
# Out:
# <Axes: >

# %%
df_examyear.plot(kind='bar')
# Out:
# <Axes: xlabel='Regents Exam'>
